# %%
import logging
from pyomo.environ import *
logging.root.setLevel(logging.NOTSET) # or logging.basicConfig(level=logging.NOTSET)

from config.default_params import create_data_dictionary
from utils.utilities import import_instance

import sys
sys.path.append("../") # go to parent dir

# %load_ext autoreload
# %autoreload 2

from evrptw import EVRPTW

from utils.graph import draw_plain_graph, draw_graph
from utils.plot import plot_interactive_graph
from utils.utilities import create_optimal_edges, merge_variable_results
from utils.utilities import parse_csv_tables, calculate_distance_matrix, generate_index_mapping
from utils.utilities import trace_routes
import pandas as pd

# %%
import json
import numpy as np

# JSON can't handle np.arrays so convert to list
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        elif isinstance(obj, tuple):
            return obj.tolist()
        elif isinstance(obj, set):
            return list(obj)
        else:
            return super(NpEncoder, self).default(obj)

# %%
def create_json_out(instace_subopt):
    
    data_out = {}
    
    for v in instace_subopt.component_objects(Var):
        data_out[v.name] = {}
        for index in v:
            try:        
                data_out[v.name][str(index)] = value(v[index])
            except:
                data_out[v.name][str(index)] = None

    json_outputs = json.dumps(data_out, cls=NpEncoder, sort_keys=True, indent=4, separators=(',', ': '))

    with open('output.json', 'w') as outfile:
        json.dump(data_out, outfile, cls=NpEncoder, sort_keys=True, indent=4, separators=(',', ': '))
        
    return json_outputs


def update_instance_json(var_list, new_concrete_instance, instance_subopt_json):
    
    for var in var_list:  
        var_instance = getattr(new_concrete_instance, var)  
        for (key, val) in instance_subopt_json[var].items():     
            if var is 'xgamma':
                var_instance[eval(key)] = val 
            else:
                var_instance[key] = val       
        setattr(new_concrete_instance, var, var_instance)
        
    return new_concrete_instance

def update_instance(var_list, new_concrete_instance, instance_subopt):
    
    for var in var_list:
        var_instance = getattr(new_concrete_instance, var)
        for (key, val) in getattr(instance_subopt, var).get_values().items():
            var_instance[key] = val
        
        setattr(new_concrete_instance, var, var_instance)
        
    return new_concrete_instance

# %%
instance = 'c106C15'

fpath = 'data/' + instance + '.csv'

m_run = EVRPTW()

duplicates = False
# m_run.solve(fpath, duplicates)

#%% testing initializing instances, solve function

# Specify solver
opt = SolverFactory('gurobi')

# Import data
instance_filepath = fpath
m_run.instance_name = instance_filepath.split('/')[-1].split('.')[0]
logging.info('Importing VRPTW MILP instance: {}'.format(m_run.instance_name))

m_run.data = import_instance(instance_filepath, duplicates)

# Create parameters
logging.info('Creating parameters')
p = create_data_dictionary(m_run.data)

# Create an instance of the AbstractModel passing in parameters
logging.info('Creating instance')
m_run.instance = m_run.m.create_instance(p)

# Solver options
solv_options = {'timelimit': 5} # fix a time limit to create suboptimal solution
    
# Solve instance
logging.info('Solving instance...')
# results = opt.solve(m_run.instance, tee=True)
results = opt.solve(m_run.instance, tee=True, options=solv_options)
logging.info('Done')
# Out:
# INFO:root:Building abstract model
# INFO:root:Defining parameters and sets
# INFO:root:Defining variables
# INFO:root:Defining constraints
# INFO:root:Defining objective
# INFO:root:Importing VRPTW MILP instance: c106C15
# INFO:root:Creating parameters
# INFO:root:Creating instance
# WARNING:pyomo.core:Initializing ordered Set start_node with a fundamentally unordered data source (type: set).  This WILL potentially lead to nondeterministic behavior in Pyomo
# WARNING:pyomo.core:Initializing ordered Set end_node with a fundamentally unordered data source (type: set).  This WILL potentially lead to nondeterministic behavior in Pyomo
# INFO:root:Solving instance...
# WARNING: Initializing ordered Set start_node with a fundamentally unordered
#     data source (type: set).  This WILL potentially lead to nondeterministic
#     behavior in Pyomo
# WARNING: Initializing ordered Set end_node with a fundamentally unordered data
#     source (type: set).  This WILL potentially lead to nondeterministic
#     behavior in Pyomo
# Using license file C:\gurobi910\win64\gurobi.lic
# Academic license - for non-commercial use only - expires 2021-04-11
# Read LP format model from file C:\Users\berwa\AppData\Local\Temp\tmpmy99e15b.pyomo.lp
# Reading time = 0.01 seconds
# x461: 1108 rows, 403 columns, 4080 nonzeros
# Changed value of parameter timelimit to 5.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1108 rows, 403 columns and 4080 nonzeros
# Model fingerprint: 0xbfaeebc6
# Variable types: 60 continuous, 343 integer (343 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+03]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 402 rows and 109 columns
# Presolve time: 0.03s
# Presolved: 706 rows, 294 columns, 4674 nonzeros
# Variable types: 54 continuous, 240 integer (240 binary)
#
# Root relaxation: objective 2.216407e+02, 94 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  221.64068    0   22          -  221.64068      -     -    0s
# H    0     0                     443.5516519  221.64068  50.0%     -    0s
# H    0     0                     396.0391101  221.64068  44.0%     -    0s
#      0     0  254.66142    0   22  396.03911  254.66142  35.7%     -    0s
# H    0     0                     332.9295011  254.66142  23.5%     -    0s
#      0     0  254.69783    0   17  332.92950  254.69783  23.5%     -    0s
#      0     0  254.69783    0   17  332.92950  254.69783  23.5%     -    0s
#      0     0  262.78117    0   34  332.92950  262.78117  21.1%     -    0s
# H    0     0                     332.1113131  262.78117  20.9%     -    0s
#      0     0  262.99977    0   38  332.11131  262.99977  20.8%     -    0s
# H    0     0                     325.6579035  262.99977  19.2%     -    0s
# H    0     0                     313.1720866  262.99977  16.0%     -    0s
# H    0     0                     303.6386882  262.99977  13.4%     -    0s
#      0     0  265.05204    0   28  303.63869  265.05204  12.7%     -    0s
#      0     0  265.55149    0   32  303.63869  265.55149  12.5%     -    0s
# H    0     0                     302.5556879  265.55149  12.2%     -    0s
#      0     0  265.62417    0   36  302.55569  265.62417  12.2%     -    0s
#      0     0  267.74824    0   35  302.55569  267.74824  11.5%     -    0s
#      0     0  268.20667    0   35  302.55569  268.20667  11.4%     -    0s
# H    0     0                     288.6691627  269.38126  6.68%     -    0s
# H    0     0                     284.7440316  269.38126  5.40%     -    0s
#      0     0  269.39201    0   29  284.74403  269.39201  5.39%     -    0s
#      0     0  269.39201    0   16  284.74403  269.39201  5.39%     -    0s
#      0     0  269.89154    0   10  284.74403  269.89154  5.22%     -    0s
# H    0     0                     271.2080378  269.89154  0.49%     -    0s
#      0     0     cutoff    0       271.20804  271.20804  0.00%     -    0s
#
# Cutting planes:
#   Learned: 3
#   Implied bound: 6
#   Clique: 1
#   MIR: 5
#   Zero half: 1
#   RLT: 6
#   Relax-and-lift: 3
#
# Explored 1 nodes (632 simplex iterations) in 0.26 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 271.208 284.744 288.669 ... 396.039
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.712080377727e+02, best bound 2.712080377727e+02, gap 0.0000%
# INFO:root:Done

# %%
# Clone the suboptimal solution
instance_subopt1 =  m_run.instance.clone()
instance_subopt2 =  m_run.instance.clone()

# Solve the suboptimal solution to optimality
results = opt.solve(instance_subopt1, tee=True)
# Out:
# Using license file C:\gurobi910\win64\gurobi.lic
# Academic license - for non-commercial use only - expires 2021-04-11
# Read LP format model from file C:\Users\berwa\AppData\Local\Temp\tmp__nkmsfa.pyomo.lp
# Reading time = 0.01 seconds
# x461: 1108 rows, 403 columns, 4080 nonzeros
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1108 rows, 403 columns and 4080 nonzeros
# Model fingerprint: 0xbfaeebc6
# Variable types: 60 continuous, 343 integer (343 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+03]
#   Objective range  [2e+00, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 402 rows and 109 columns
# Presolve time: 0.03s
# Presolved: 706 rows, 294 columns, 4674 nonzeros
# Variable types: 54 continuous, 240 integer (240 binary)
#
# Root relaxation: objective 2.216407e+02, 94 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  221.64068    0   22          -  221.64068      -     -    0s
# H    0     0                     443.5516519  221.64068  50.0%     -    0s
# H    0     0                     396.0391101  221.64068  44.0%     -    0s
#      0     0  254.66142    0   22  396.03911  254.66142  35.7%     -    0s
# H    0     0                     332.9295011  254.66142  23.5%     -    0s
#      0     0  254.69783    0   17  332.92950  254.69783  23.5%     -    0s
#      0     0  254.69783    0   17  332.92950  254.69783  23.5%     -    0s
#      0     0  262.78117    0   34  332.92950  262.78117  21.1%     -    0s
# H    0     0                     332.1113131  262.78117  20.9%     -    0s
#      0     0  262.99977    0   38  332.11131  262.99977  20.8%     -    0s
# H    0     0                     325.6579035  262.99977  19.2%     -    0s
# H    0     0                     313.1720866  262.99977  16.0%     -    0s
# H    0     0                     303.6386882  262.99977  13.4%     -    0s
#      0     0  265.05204    0   28  303.63869  265.05204  12.7%     -    0s
#      0     0  265.55149    0   32  303.63869  265.55149  12.5%     -    0s
# H    0     0                     302.5556879  265.55149  12.2%     -    0s
#      0     0  265.62417    0   36  302.55569  265.62417  12.2%     -    0s
#      0     0  267.74824    0   35  302.55569  267.74824  11.5%     -    0s
#      0     0  268.20667    0   35  302.55569  268.20667  11.4%     -    0s
# H    0     0                     288.6691627  269.38126  6.68%     -    0s
# H    0     0                     284.7440316  269.38126  5.40%     -    0s
#      0     0  269.39201    0   29  284.74403  269.39201  5.39%     -    0s
#      0     0  269.39201    0   16  284.74403  269.39201  5.39%     -    0s
#      0     0  269.89154    0   10  284.74403  269.89154  5.22%     -    0s
# H    0     0                     271.2080378  269.89154  0.49%     -    0s
#      0     0     cutoff    0       271.20804  271.20804  0.00%     -    0s
#
# Cutting planes:
#   Learned: 3
#   Implied bound: 6
#   Clique: 1
#   MIR: 5
#   Zero half: 1
#   RLT: 6
#   Relax-and-lift: 3
#
# Explored 1 nodes (632 simplex iterations) in 0.26 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 271.208 284.744 288.669 ... 396.039
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.712080377727e+02, best bound 2.712080377727e+02, gap 0.0000%

# %%
instance_subopt1.obj()
# Out:
# 271.2080377727125

# %%
#%% testing updating instance variables

var_list = ['xgamma', 'xw', 'xq', 'xa']
m_run.instance = m_run.m.create_instance(p)
m_run.instance = update_instance(var_list, m_run.instance, instance_subopt2)

# m_run.instance.xw.pprint()
# Out:
# WARNING:pyomo.core:Initializing ordered Set start_node with a fundamentally unordered data source (type: set).  This WILL potentially lead to nondeterministic behavior in Pyomo
# WARNING:pyomo.core:Initializing ordered Set end_node with a fundamentally unordered data source (type: set).  This WILL potentially lead to nondeterministic behavior in Pyomo
# WARNING: Initializing ordered Set start_node with a fundamentally unordered
#     data source (type: set).  This WILL potentially lead to nondeterministic
#     behavior in Pyomo
# WARNING: Initializing ordered Set end_node with a fundamentally unordered data
#     source (type: set).  This WILL potentially lead to nondeterministic
#     behavior in Pyomo
# xw : Size=22, Index=V01_
#     Key : Lower : Value              : Upper : Fixed : Stale : Domain
#     C10 :     0 :              845.0 :  None : False : False : NonNegativeReals
#     C13 :     0 :             1106.0 :  None : False : False : NonNegativeReals
#     C18 :     0 :              418.0 :  None : False : False : NonNegativeReals
#     C19 :     0 :              513.0 :  None : False : False : NonNegativeReals
#     C30 :     0 :  307.3844718719117 :  None : False : False : NonNegativeReals
#     C33 :     0 : 407.91726006088516 :  None : False : False : NonNegativeReals
#     C35 :     0 :              655.0 :  None : False : False : NonNegativeReals
#     C40 :     0 :              199.0 :  None : False : False : NonNegativeReals
#     C44 :     0 : 105.99999999999953 :  None : False : False : NonNegativeReals
#     C50 :     0 : 298.21954445729284 :  None : False : False : NonNegativeReals
#     C59 :     0 :               66.0 :  None : False : False : NonNegativeReals
#     C61 :     0 :             1064.0 :  None : False : False : NonNegativeReals
#     C85 :     0 : 29.732137494637072 :  None : False : False : NonNegativeReals
#     C95 :     0 : 234.16301810938853 :  None : False : False : NonNegativeReals
#     C98 :     0 : 137.75989387195568 :  None : False : False : NonNegativeReals
#      D0 :     0 :                0.0 :  None : False : False : NonNegativeReals
#      D1 :     0 :             1236.0 :  None : False : False : NonNegativeReals
#      S0 :     0 :  951.7630546142402 :  None : False : False : NonNegativeReals
#     S13 :     0 :  762.0293863659265 :  None : False : False : NonNegativeReals
#     S15 :     0 :             1236.0 :  None : False : False : NonNegativeReals
#      S3 :     0 : 482.00455898252903 :  None : False : False : NonNegativeReals
#      S7 :     0 :   828.145242251701 :  None : False : False : NonNegativeReals

# %%
opt.solve(m_run.instance, tee=True)
# Out:
# --------------------------------------------
# Warning: your license will expire in 2 days
# --------------------------------------------
#
# Using license file C:\Users\berwa\gurobi.lic
# Academic license - for non-commercial use only - expires 2021-02-09
# Read LP format model from file C:\Users\berwa\AppData\Local\Temp\tmpu4ytl1az.pyomo.lp
# Reading time = 0.01 seconds
# x551: 1350 rows, 487 columns, 5012 nonzeros
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1350 rows, 487 columns and 5012 nonzeros
# Model fingerprint: 0x3eb94f6e
# Variable types: 66 continuous, 421 integer (421 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed
seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 371.7 372.35 376.653 ... 509.028
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.717001997058e+02, best bound 3.717001997058e+02, gap 0.0000%
# {'Problem': [{'Name': 'x551', 'Lower bound': 371.7001997057637, 'Upper bound': 371.7001997057637, 'Number of objectives': 1, 'Number of constraints': 1350, 'Number of variables': 487, 'Number of binary variables': 421, 'Number of integer variables': 421, 'Number of continuous variables': 66, 'Number of nonzeros': 5012, 'Sense': 'minimize'}], 'Solver': [{'Status': 'ok', 'Return code': '0', 'Message': 'Model was solved to optimality (subject to tolerances), and an optimal solution is available.', 'Termination condition': 'optimal', 'Termination message': 'Model was solved to optimality (subject to tolerances), and an optimal solution is available.', 'Wall time': '13.845621109008789', 'Error rc': 0, 'Time': 14.19668436050415}], 'Solution': [OrderedDict([('number of solutions', 0), ('number of solutions displayed', 0)])]}

# %%
#%% creating json output

json_outputs = create_json_out(instance_subopt2)
print(json_outputs)
# Out:
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D0,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D0,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,D1]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,D1]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,S0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,S0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,S3]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,S3]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,S7]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,S7]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,S13]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,S13]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,S15]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,S15]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C61]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C61]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C30]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C30]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C98]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C98]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C59]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C59]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C35]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C35]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C13]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C13]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C10]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C10]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C44]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C44]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C50]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C50]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C95]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C95]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C18]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C18]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C33]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C33]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C85]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C85]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C19]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C19]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[D1,C40]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[D1,C40]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[S0,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[S0,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[S0,S0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[S0,S0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[S3,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[S3,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[S3,S3]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[S3,S3]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[S7,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[S7,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[S7,S7]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[S7,S7]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[S13,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[S13,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[S13,S13]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[S13,S13]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[S15,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[S15,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[S15,S15]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[S15,S15]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C61,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C61,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C61,C61]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C61,C61]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C30,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C30,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C30,C30]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C30,C30]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C98,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C98,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C98,C98]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C98,C98]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C59,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C59,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C59,C59]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C59,C59]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C35,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C35,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C35,C35]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C35,C35]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C13,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C13,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C13,C13]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C13,C13]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C10,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C10,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C10,C10]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C10,C10]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C44,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C44,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C44,C44]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C44,C44]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C50,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C50,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C50,C50]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C50,C50]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C95,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C95,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C95,C95]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C95,C95]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C18,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C18,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C18,C18]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C18,C18]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C33,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C33,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C33,C33]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C33,C33]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C85,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C85,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C85,C85]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C85,C85]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C19,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C19,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C19,C19]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C19,C19]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C40,D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C40,D0]
# ERROR:pyomo.core:evaluating object as numeric value: xgamma[C40,C40]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xgamma[C40,C40]
# ERROR:pyomo.core:evaluating object as numeric value: xa[D0]
#     (object: <class 'pyomo.core.base.var._GeneralVarData'>)
# No value for uninitialized NumericValue object xa[D0]
# ERROR: evaluating object as numeric value: xgamma[D0,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D0,D0]
# ERROR: evaluating object as numeric value: xgamma[D1,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,D0]
# ERROR: evaluating object as numeric value: xgamma[D1,D1]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,D1]
# ERROR: evaluating object as numeric value: xgamma[D1,S0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,S0]
# ERROR: evaluating object as numeric value: xgamma[D1,S3]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,S3]
# ERROR: evaluating object as numeric value: xgamma[D1,S7]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,S7]
# ERROR: evaluating object as numeric value: xgamma[D1,S13]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,S13]
# ERROR: evaluating object as numeric value: xgamma[D1,S15]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,S15]
# ERROR: evaluating object as numeric value: xgamma[D1,C61]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C61]
# ERROR: evaluating object as numeric value: xgamma[D1,C30]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C30]
# ERROR: evaluating object as numeric value: xgamma[D1,C98]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C98]
# ERROR: evaluating object as numeric value: xgamma[D1,C59]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C59]
# ERROR: evaluating object as numeric value: xgamma[D1,C35]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C35]
# ERROR: evaluating object as numeric value: xgamma[D1,C13]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C13]
# ERROR: evaluating object as numeric value: xgamma[D1,C10]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C10]
# ERROR: evaluating object as numeric value: xgamma[D1,C44]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C44]
# ERROR: evaluating object as numeric value: xgamma[D1,C50]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C50]
# ERROR: evaluating object as numeric value: xgamma[D1,C95]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C95]
# ERROR: evaluating object as numeric value: xgamma[D1,C18]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C18]
# ERROR: evaluating object as numeric value: xgamma[D1,C33]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C33]
# ERROR: evaluating object as numeric value: xgamma[D1,C85]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C85]
# ERROR: evaluating object as numeric value: xgamma[D1,C19]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C19]
# ERROR: evaluating object as numeric value: xgamma[D1,C40]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[D1,C40]
# ERROR: evaluating object as numeric value: xgamma[S0,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[S0,D0]
# ERROR: evaluating object as numeric value: xgamma[S0,S0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[S0,S0]
# ERROR: evaluating object as numeric value: xgamma[S3,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[S3,D0]
# ERROR: evaluating object as numeric value: xgamma[S3,S3]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[S3,S3]
# ERROR: evaluating object as numeric value: xgamma[S7,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[S7,D0]
# ERROR: evaluating object as numeric value: xgamma[S7,S7]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[S7,S7]
# ERROR: evaluating object as numeric value: xgamma[S13,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[S13,D0]
# ERROR: evaluating object as numeric value: xgamma[S13,S13]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[S13,S13]
# ERROR: evaluating object as numeric value: xgamma[S15,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[S15,D0]
# ERROR: evaluating object as numeric value: xgamma[S15,S15]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[S15,S15]
# ERROR: evaluating object as numeric value: xgamma[C61,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C61,D0]
# ERROR: evaluating object as numeric value: xgamma[C61,C61]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C61,C61]
# ERROR: evaluating object as numeric value: xgamma[C30,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C30,D0]
# ERROR: evaluating object as numeric value: xgamma[C30,C30]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C30,C30]
# ERROR: evaluating object as numeric value: xgamma[C98,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C98,D0]
# ERROR: evaluating object as numeric value: xgamma[C98,C98]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C98,C98]
# ERROR: evaluating object as numeric value: xgamma[C59,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C59,D0]
# ERROR: evaluating object as numeric value: xgamma[C59,C59]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C59,C59]
# ERROR: evaluating object as numeric value: xgamma[C35,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C35,D0]
# ERROR: evaluating object as numeric value: xgamma[C35,C35]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C35,C35]
# ERROR: evaluating object as numeric value: xgamma[C13,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C13,D0]
# ERROR: evaluating object as numeric value: xgamma[C13,C13]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C13,C13]
# ERROR: evaluating object as numeric value: xgamma[C10,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C10,D0]
# ERROR: evaluating object as numeric value: xgamma[C10,C10]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C10,C10]
# ERROR: evaluating object as numeric value: xgamma[C44,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C44,D0]
# ERROR: evaluating object as numeric value: xgamma[C44,C44]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C44,C44]
# ERROR: evaluating object as numeric value: xgamma[C50,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C50,D0]
# ERROR: evaluating object as numeric value: xgamma[C50,C50]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C50,C50]
# ERROR: evaluating object as numeric value: xgamma[C95,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C95,D0]
# ERROR: evaluating object as numeric value: xgamma[C95,C95]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C95,C95]
# ERROR: evaluating object as numeric value: xgamma[C18,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C18,D0]
# ERROR: evaluating object as numeric value: xgamma[C18,C18]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C18,C18]
# ERROR: evaluating object as numeric value: xgamma[C33,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C33,D0]
# ERROR: evaluating object as numeric value: xgamma[C33,C33]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C33,C33]
# ERROR: evaluating object as numeric value: xgamma[C85,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C85,D0]
# ERROR: evaluating object as numeric value: xgamma[C85,C85]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C85,C85]
# ERROR: evaluating object as numeric value: xgamma[C19,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C19,D0]
# ERROR: evaluating object as numeric value: xgamma[C19,C19]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C19,C19]
# ERROR: evaluating object as numeric value: xgamma[C40,D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C40,D0]
# ERROR: evaluating object as numeric value: xgamma[C40,C40]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xgamma[C40,C40]
# ERROR: evaluating object as numeric value: xa[D0]
#         (object: <class 'pyomo.core.base.var._GeneralVarData'>)
#     No value for uninitialized NumericValue object xa[D0]
# {
#     "xa": {
#         "C10": 35.21933542766848,
#         "C13": 30.805843601498715,
#         "C18": 11.708203932499288,
#         "C19": 6.708203932499288,
#         "C30": 32.32373206058758,
#         "C33": 24.292080710576904,
#         "C35": 18.461128815731605,
#         "C40": 53.20934077146199,
#         "C44": 56.20934077146199,
#         "C50": 43.989796314169105,
#         "C59": 42.6929037140838,
#         "C61": 23.48353100178523,
#         "C85": 48.017862505362984,
#         "C95": 23.58698189061022,
#         "C98": 29.99010612804307,
#         "D0": null,
#         "D1": 0.0,
#         "S0": 0.0,
#         "S13": 1.4317424498052063,
#         "S15": 0.0,
#         "S3": 0.0,
#         "S7": 0.0
#     },
#     "xgamma": {
#         "('C10', 'C10')": null,
#         "('C10', 'C13')": -0.0,
#         "('C10', 'C18')": -0.0,
#         "('C10', 'C19')": 0.0,
#         "('C10', 'C30')": 0.0,
#         "('C10', 'C33')": 0.0,
#         "('C10', 'C35')": 0.0,
#         "('C10', 'C40')": 0.0,
#         "('C10', 'C44')": 0.0,
#         "('C10', 'C50')": -0.0,
#         "C33": 407.91726006088516,
#         "C35": 655.0,
#         "C40": 199.0,
#         "C44": 105.99999999999953,
#         "C50": 298.21954445729284,
#         "C59": 66.0,
#         "C61": 1064.0,
#         "C85": 29.732137494637072,
#         "C95": 234.16301810938853,
#         "C98": 137.75989387195568,
#         "D0": 0.0,
#         "D1": 1236.0,
#         "S0": 951.7630546142402,
#         "S13": 762.0293863659265,
#         "S15": 1236.0,
#         "S3": 482.00455898252903,
#         "S7": 828.145242251701
#     }
# }

# %%
#%% loading json output

with  open('output.json', 'r') as inputfile:
    json_outputs = json.load(inputfile)

# %%
var_list = ['xgamma', 'xw', 'xq', 'xa']
m_run.instance = m_run.m.create_instance(p)
# m_run.instance = update_instance_json(var_list, m_run.instance, json_outputs)
# m_run.instance.xw.pprint()
# m_run.instance.obj()
# Out:
# WARNING:pyomo.core:Initializing ordered Set start_node with a fundamentally unordered data source (type: set).  This WILL potentially lead to nondeterministic behavior in Pyomo
# WARNING:pyomo.core:Initializing ordered Set end_node with a fundamentally unordered data source (type: set).  This WILL potentially lead to nondeterministic behavior in Pyomo
# WARNING: Initializing ordered Set start_node with a fundamentally unordered
#     data source (type: set).  This WILL potentially lead to nondeterministic
#     behavior in Pyomo
# WARNING: Initializing ordered Set end_node with a fundamentally unordered data
#     source (type: set).  This WILL potentially lead to nondeterministic
#     behavior in Pyomo

# %%
opt.solve(m_run.instance, tee=True)
# Out:
# --------------------------------------------
# Warning: your license will expire in 2 days
# --------------------------------------------
#
# Using license file C:\Users\berwa\gurobi.lic
# Academic license - for non-commercial use only - expires 2021-02-09
# Read LP format model from file C:\Users\berwa\AppData\Local\Temp\tmp6grhyp22.pyomo.lp
# Reading time = 0.01 seconds
# x551: 1350 rows, 487 columns, 5012 nonzeros
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1350 rows, 487 columns and 5012 nonzeros
# Model fingerprint: 0x3eb94f6e
# Variable types: 66 continuous, 421 integer (421 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 343 rows and 92 columns
# Presolve time: 0.05s
# Presolved: 1007 rows, 395 columns, 7091 nonzeros
# Variable types: 60 continuous, 335 integer (335 binary)
# Found heuristic solution: objective 842.0287527
#
# Root relaxation: objective 2.139517e+02, 132 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  213.95167    0   36  842.02875  213.95167  74.6%     -    0s
# H    0     0                     810.9288006  213.95167  73.6%     -    0s
# H    0     0                     772.9091881  213.95167  72.3%     -    0s
# H    0     0                     689.9982016  213.95167  69.0%     -    0s
#      0     0  243.58108    0   42  689.99820  243.58108  64.7%     -    0s
# H    0     0                     509.0279171  243.58108  52.1%     -    0s
#      0     0  243.63258    0   31  509.02792  243.63258  52.1%     -    0s
#      0     0  243.63647    0   31  509.02792  243.63647  52.1%     -    0s
# H    0     0                     461.7413440  243.63647  47.2%     -    0s
#      0     0  259.31184    0   47  461.74134  259.31184  43.8%     -    0s
# H    0     0                     417.8181153  259.31184  37.9%     -    0s
#      0     0  259.89639    0   51  417.81812  259.89639  37.8%     -    0s
#      0     0  259.89639    0   51  417.81812  259.89639  37.8%     -    0s
#      0     0  269.80917    0   41  417.81812  269.80917  35.4%     -    0s
#      0     0  269.82174    0   40  417.81812  269.82174  35.4%     -    0s
#      0     0  270.78680    0   44  417.81812  270.78680  35.2%     -    0s
#      0     0  270.84026    0   48  417.81812  270.84026  35.2%     -    0s
#      0     0  270.86285    0   47  417.81812  270.86285  35.2%     -    0s
#      0     0  270.87311    0   47  417.81812  270.87311  35.2%     -    0s
#      0     0  275.44726    0   46  417.81812  275.44726  34.1%     -    0s
#      0     0  276.24158    0   46  417.81812  276.24158  33.9%     -    0s
#      0     0  276.24158    0   46  417.81812  276.24158  33.9%     -    0s
#      0     0  276.36155    0   43  417.81812  276.36155  33.9%     -    0s
#      0     0  276.41579    0   48  417.81812  276.41579  33.8%     -    0s
#      0     0  276.41579    0   48  417.81812  276.41579  33.8%     -    0s
# H    0     0                     414.0638522  276.41579  33.2%     -    0s
#      0     0  276.86982    0   43  414.06385  276.86982  33.1%     -    0s
#      0     0  276.86982    0   43  414.06385  276.86982  33.1%     -    0s
#      0     0  276.87309    0   43  414.06385  276.87309  33.1%     -    0s
#      0     0  276.87309    0   43  414.06385  276.87309  33.1%     -    0s
#      0     0  276.87309    0   40  414.06385  276.87309  33.1%     -    0s
#      0     2  276.89853    0   40  414.06385  276.89853  33.1%     -    0s
# H   71    58                     407.6552653  280.91250  31.1%  18.4    0s
# H  116    77                     398.6939965  284.50853  28.6%  15.7    0s
# H 1058   510                     385.7149546  295.56052  23.4%  14.7    2s
# H 1058   484                     376.6528042  295.56052  21.5%  14.7    2s
# H 1635   580                     372.3501356  303.49050  18.5%  20.9    4s
#   2126   614  360.20496   33   28  372.35014  306.19456  17.8%  21.6    5s
# * 5971  1374              40     371.7001997  327.36557  11.9%  22.0    7s
#   9157  1845  358.12708   24   25  371.70020  334.02123  10.1%  21.6   10s
#  17782  1142  368.83908   33   10  371.70020  350.49571  5.70%  20.3   15s
#
# Cutting planes:
#   Learned: 15
#   Gomory: 16
#   Cover: 16
#   Implied bound: 30
#   Projected implied bound: 12
#   Clique: 1
#   MIR: 59
#   StrongCG: 3
#   Flow cover: 117
#   GUB cover: 7
#   Inf proof: 26
#   Zero half: 28
#   RLT: 17
#   Relax-and-lift: 17
#
# Explored 21821 nodes (426806 simplex iterations) in 17.16 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 371.7 372.35 376.653 ... 509.028
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.717001997058e+02, best bound 3.717001997058e+02, gap 0.0000%
# {'Problem': [{'Name': 'x551', 'Lower bound': 371.7001997057637, 'Upper bound': 371.7001997057637, 'Number of objectives': 1, 'Number of constraints': 1350, 'Number of variables': 487, 'Number of binary variables': 421, 'Number of integer variables': 421, 'Number of continuous variables': 66, 'Number of nonzeros': 5012, 'Sense': 'minimize'}], 'Solver': [{'Status': 'ok', 'Return code': '0', 'Message': 'Model was solved to optimality (subject to tolerances), and an optimal solution is available.', 'Termination condition': 'optimal', 'Termination message': 'Model was solved to optimality (subject to tolerances), and an optimal solution is available.', 'Wall time': '17.16280174255371', 'Error rc': 0, 'Time': 17.52383303642273}], 'Solution': [OrderedDict([('number of solutions', 0), ('number of solutions displayed', 0)])]}
